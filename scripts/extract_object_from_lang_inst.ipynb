# %%
from collections import defaultdict
import pandas as pd
import numpy as np
import pickle
import h5py
import spacy
import csv
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.cluster.hierarchy import linkage, fcluster

# %%
# Load Droid metadata
metadata_fp = "./all_droid_metadata.pkl"
df = pd.read_pickle(metadata_fp)

# %%
# Filter only successful demos with any language instruction
successful_df = df[df['success'] == True]
successful_with_inst_df = successful_df.loc[~((successful_df['language_instruction_1'] == '') & 
              (successful_df['language_instruction_2'] == '') & 
              (successful_df['language_instruction_3'] == ''))]
successful_with_inst_df.dropna(subset=['language_instruction_1', 'language_instruction_2', 'language_instruction_3'], how='all')
# Out:
#              Demo                                           filepath  \
# 3        demo_100  gs://xembodiment_data/r2d2/r2d2-data-full/TRI/...
# 4       demo_1000  gs://xembodiment_data/r2d2/r2d2-data-full/REAL...
# 5      demo_10000  gs://xembodiment_data/r2d2/r2d2-data-full/RAIL...
# 6      demo_10001  gs://xembodiment_data/r2d2/r2d2-data-full/TRI/...
# 7      demo_10002  gs://xembodiment_data/r2d2/r2d2-data-full/CLVR...
# ...           ...                                                ...
# 92219   demo_9987  gs://xembodiment_data/r2d2/r2d2-data-full/ILIA...
# 92223   demo_9990  gs://xembodiment_data/r2d2/r2d2-data-full/IRIS...
# 92228   demo_9995  gs://xembodiment_data/r2d2/r2d2-data-full/CLVR...
# 92229   demo_9996  gs://xembodiment_data/r2d2/r2d2-data-full/Gupt...
# 92231   demo_9998  gs://xembodiment_data/r2d2/r2d2-data-full/Penn...
#
#                                    recording_folder_path  success  \
# 3      gs://xembodiment_data/r2d2/r2d2-data-full/TRI/...     True
# 4      gs://xembodiment_data/r2d2/r2d2-data-full/REAL...     True
# 5      gs://xembodiment_data/r2d2/r2d2-data-full/RAIL...     True
# 6      gs://xembodiment_data/r2d2/r2d2-data-full/TRI/...     True
# 7      gs://xembodiment_data/r2d2/r2d2-data-full/CLVR...     True
# ...                                                  ...      ...
# 92219  gs://xembodiment_data/r2d2/r2d2-data-full/ILIA...     True
# 92223  gs://xembodiment_data/r2d2/r2d2-data-full/IRIS...     True
# 92228  gs://xembodiment_data/r2d2/r2d2-data-full/CLVR...     True
# 92229  gs://xembodiment_data/r2d2/r2d2-data-full/Gupt...     True
# 92231  gs://xembodiment_data/r2d2/r2d2-data-full/Penn...     True
#
#                                   language_instruction_1  \
# 3             Put the coffee capsule in the coffee maker
# 4                  Put the tomato inside the silver bowl
# 5      Remove the gray toy from the bowl and put in i...
# 6      Pick the popcorn on the napkin using the fork ...
# 7                 Put the cloth on the countertop shield
# ...                                                  ...
# 92219           Put the grey backpack on the black chair
# 92223                      Move the white mug backwards.
# 92228           Hang the white cloth on the wooden board
# 92229                            Close the bottom drawer
# 92231      Mix the contents of the bowl with the spatula
#
#                                   language_instruction_2  \
# 3
# 4                 Pick the tomato and put it in the bowl
# 5                     Remove the grey doll from the bowl
# 6
# 7              Pick up the cloth and put it on the glass
# ...                                                  ...
# 92219  Move the black bag from the brown couch to the...
# 92223                    Move the white mug to the right
# 92228                     Hang the cloth on wooden stand
# 92229                                   Close the drawer
# 92231                Use the spatula to stir in the bowl
#
#                                   language_instruction_3  \
# 3
# 4               Put the toy tomato in the colourless bow
# 5                Put the grey plush toy inside the sink.
# 6
# 7                    Hang the cloth on the glass barrier
# ...                                                  ...
# 92219    Pick up the backpack and put it on the armchair
# 92223                          Move the cup to the right
# 92228  Pick up the towel from the table and put it on...
# 92229        Close the bottom drawer of the left cabinet
# 92231                   Use the ladle to stir in the bow
#
#              colors_in_demo  num_actions  max_ee_velocity  ...       lab  \
# 3                        []          236         1.523148  ...       TRI
# 4          [tomato, silver]          180         1.542357  ...      REAL
# 5              [gray, grey]          286         0.772116  ...      RAIL
# 6                        []          447         1.608746  ...       TRI
# 7                        []          154         1.613444  ...      CLVR
# ...                     ...          ...              ...  ...       ...
# 92219  [black, grey, brown]          342         1.707058  ...       NaN
# 92223               [white]          176         0.950902  ...       NaN
# 92228               [white]          175         1.324791  ...      CLVR
# 92229                    []           61         1.491070  ...  GuptaLab
# 92231                    []          470         1.165797  ...   PennPAL
#
#              date               timestamp      scene_id  \
# 3      2023-11-27  2023-11-27-15h-41m-41s  8.949827e+09
# 4      2023-07-25  2023-07-25-14h-33m-12s  8.626796e+09
# 5      2023-10-22  2023-10-22-11h-27m-25s  1.560521e+08
# 6      2023-11-29  2023-11-29-10h-38m-10s  5.445648e+08
# 7      2023-06-25  2023-06-25-18h-54m-45s  7.489911e+09
# ...           ...                     ...           ...
# 92219         NaN                     NaN           NaN
# 92223         NaN                     NaN           NaN
# 92228  2023-06-25  2023-06-25-18h-03m-42s  7.489911e+09
# 92229  2023-06-18  2023-06-18-18h-01m-12s  5.235850e+09
# 92231  2023-07-19  2023-07-19-17h-12m-46s  2.927338e+09
#
#                                                     task  \
# 3      Do any task, and then reset the scene.\n\nSugg...
# 4      Move object into or out of container (ex: draw...
# 5      Move object into or out of container (ex: draw...
# 6      Move object into or out of container (ex: draw...
# 7      Hang or unhang object (ex: towel on hook, clot...
# ...                                                  ...
# 92219                                                NaN
# 92223                                                NaN
# 92228  Hang or unhang object (ex: towel on hook, clot...
# 92229  Open or close slidable objects (ex: toaster, d...
# 92231  Use object to stir something (ex: almonds in a...
#
#                    building trajectory_length  \
# 3                       TRI             237.0
# 4             Glen's office             181.0
# 5                      RAIL             287.0
# 6                       TRI             448.0
# 7                     KAIST             155.0
# ...                     ...               ...
# 92219                   NaN               NaN
# 92223                   NaN               NaN
# 92228                 KAIST             176.0
# 92229  Smith Hall Fetch Lab              62.0
# 92231       Penn Levine 457             471.0
#
#                                     wrist_cam_extrinsics  \
# 3      [0.2400873129864906, -0.04782164495006405, 0.4...
# 4      [0.2865870255047073, -0.050823464446027894, 0....
# 5      [0.2305277513568585, -0.09859850976796172, 0.4...
# 6      [0.3198158524363394, 0.161796845437758, 0.3666...
# 7      [0.3013884475276124, -0.04683488909072194, 0.3...
# ...                                                  ...
# 92219                                                 []
# 92223                                                 []
# 92228  [0.32261260712040685, 0.10035459296743669, 0.5...
# 92229  [0.34309100627456185, 0.11247263175121133, 0.4...
# 92231  [0.2889496286547031, -0.0003705044035592145, 0...
#
#                                      ext1_cam_extrinsics  \
# 3      [0.0863697908298307, 0.6370271737027244, 0.421...
# 4      [-0.0022482606920192078, -0.40645056851965927,...
# 5      [0.25415971284823435, -0.32439911544807526, 0....
# 6      [0.16701060169204435, 0.39995461738548554, 0.3...
# 7      [0.04093385111638796, 0.32573132392889403, 0.2...
# ...                                                  ...
# 92219                                                 []
# 92223                                                 []
# 92228  [0.04093385111638796, 0.32573132392889403, 0.2...
# 92229  [0.06126845421106433, 0.4951337668615451, 0.66...
# 92231  [0.3677864577228833, 0.5347497780719984, 0.454...
#
#                                      ext2_cam_extrinsics
# 3      [0.23703966939939874, -0.5803646239333268, 0.6...
# 4      [0.2806535855443205, 0.5100490134107646, 0.556...
# 5      [0.3569127895668578, 0.5353923486172769, 0.315...
# 6      [0.14098025509586265, -0.5490224802945189, 0.5...
# 7      [0.08229829614709473, -0.321123667067028, 0.23...
# ...                                                  ...
# 92219                                                 []
# 92223                                                 []
# 92228  [0.08229829614709473, -0.321123667067028, 0.23...
# 92229  [-0.17495316663380056, -0.5501611345841874, 0....
# 92231  [0.10743745966081596, -0.5427977832079363, 0.5...
#
# [49895 rows x 28 columns]

# %%
# Combine the three language instructions into one
successful_with_inst_df.loc[:, 'combined_instructions'] = successful_with_inst_df[['language_instruction_1', 'language_instruction_2', 'language_instruction_3']].agg(' '.join, axis=1)

# Preprocess text
def preprocess_text(text):
    text = text.lower()  # Lowercase the text
    text = ''.join([char for char in text if char.isalnum() or char.isspace()])
    return text

successful_with_inst_df.loc[:, 'combined_instructions'] = successful_with_inst_df['combined_instructions'].apply(preprocess_text)
successful_with_inst_df['combined_instructions'] = successful_with_inst_df['combined_instructions'].str.strip()
combined_inst_df = successful_with_inst_df[['Demo', 'combined_instructions', 'building', 'success']]
combined_inst_df
# Out:
# /var/folders/c1/5_fch2z17mz0h1_rqcpt6t380000gn/T/ipykernel_31842/2030233973.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful_with_inst_df.loc[:, 'combined_instructions'] = successful_with_inst_df[['language_instruction_1', 'language_instruction_2', 'language_instruction_3']].agg(' '.join, axis=1)
# /var/folders/c1/5_fch2z17mz0h1_rqcpt6t380000gn/T/ipykernel_31842/2030233973.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful_with_inst_df['combined_instructions'] = successful_with_inst_df['combined_instructions'].str.strip()
#              Demo                              combined_instructions  \
# 3        demo_100         put the coffee capsule in the coffee maker
# 4       demo_1000  put the tomato inside the silver bowl pick the...
# 5      demo_10000  remove the gray toy from the bowl and put in i...
# 6      demo_10001  pick the popcorn on the napkin using the fork ...
# 7      demo_10002  put the cloth on the countertop shield pick up...
# ...           ...                                                ...
# 92219   demo_9987  put the grey backpack on the black chair move ...
# 92223   demo_9990  move the white mug backwards move the white mu...
# 92228   demo_9995  hang the white cloth on the wooden board hang ...
# 92229   demo_9996  close the bottom drawer close the drawer close...
# 92231   demo_9998  mix the contents of the bowl with the spatula ...
#
#                    building  success
# 3                       TRI     True
# 4             Glen's office     True
# 5                      RAIL     True
# 6                       TRI     True
# 7                     KAIST     True
# ...                     ...      ...
# 92219                   NaN     True
# 92223                   NaN     True
# 92228                 KAIST     True
# 92229  Smith Hall Fetch Lab     True
# 92231       Penn Levine 457     True
#
# [49895 rows x 4 columns]

# %%
# Extract objects from combined language instructions
nlp = spacy.load("en_core_web_sm")

def extract_object(sentence):
    doc = nlp(sentence)
    obj = [token.text for token in doc if token.dep_ in ['dobj', 'pobj']]
    # return " ".join(obj) if obj else ""
    return obj[0] if obj else ""

clustered_dict = defaultdict(list)

for demo_id, sentence in zip(combined_inst_df['Demo'], combined_inst_df['combined_instructions']):
    obj = extract_object(sentence)
    if obj in clustered_dict:
        clustered_dict[obj].append((demo_id, sentence))
    else:
        clustered_dict[obj] = [(demo_id, sentence)]

# %%
clustered_dict.keys()
# Out:
# dict_keys(['marker', 'lid', 'object', 'towel', 'cup', 'pen', 'bottle', 'drawer', 'cloth', 'block', 'door', 'spoon', 'toy', 'bowl', 'switch', 'mug', 'contents', 'button', 'objects', 'box', 'band', 'pot', 'tape', 'faucet', 'plate', 'cube', 'cable', 'can', 'screwdriver', 'packet', 'tap', 'cups', 'fork', 'bottles', 'book', 'shirt', 'glass', 'blocks', 'bag', 'stick', 'lever', 'ball', '', 'curtain', 'item', 'napkin', 'table', 'rope', 'paper', 'bin', 'spatula', 'nozzle', 'clothes', 'some', 'tissue', 'cap', 'plushie', 'container', 'handle', 'thing', 'remote', 'knife', 'top', 'pan', 'basket', 'ring', 'jar', 'bar', 'turn', 'things', 'pack', 'light', 'elastic', 'sponge', 'sharpie', 'brush', 'kettle', 'straw', 'clothing', 'cabinet', 'one', 'piece', 'ropes', 'pepper', 'lamp', 'slice', 'maker', 'tshirt', 'hanger', 'mouse', 'tube', 'pillow', 'knob', 'sachet', 'doll', 'orange', 'shaker', 'spout', 'duck', 'toaster', 'pencil', 'tool', 'plush', 'plushy', 'press', 'microwave', 'cellar', 'plastic', 'toys', 'wrench', 'sock', 'rod', 'rings', 'blanket', 'doors', 'egg', 'papers', 'charger', 'items', 'roll', 'towels', 'key', 'eraser', 'compartment', 'banana', 'pieces', 'shoe', 'toothbrush', 'holder', 'sweatshirt', 'laptop', 'cupboard', 'pots', 'case', 'duster', 'head', 'chair', 'lemon', 'counter', 'glue', 'pod', 'soda', 'cover', 'pair', 'shirts', 'control', 'fruits', 'square', 'bowls', 'cord', 'machine', 'beans', 'jacket', 'cylinder', 'keys', 'grey', 'stapler', 'car', 'water', 'grapes', 'cob', 'spoonful', 'brick', 'side', 'tomato', 'stand', 'position', 'pillows', 'tongs', 'containers', 'tray', 'carrot', 'socks', 'push', 'tissues', 'hat', 'lunchbox', 'scissors', 'chip', 'blinds', 'capsule', 'folk', 'peg', 'pineapple', 'lego', 'cloths', 'sweets', 'candy', 'chopstick', 'snack', 'jersey', 'basketball', 'fries', 'scoop', 'hoodie', 'legos', 'coat', 'part', 'bread', 'ladle', 'flask', 'letter', 'disc', 'broccoli', 'circles', 'sneaker', 'jug', 'metal', 'rag', 'sachets', 'right', 'cubes', 'cooker', 'discs', 'wipe', 'slider', 'caps', 'fleece', 'tiles', 'chamber', 'toothpaste', 'coffeemaker', 'circle', 'shelf', 'the', 'tshirts', 'wallet', 'animal', 'bear', 'belt', 'disk', 'potato', 'dispenser', 'content', 'chips', 'crayon', 'slices', 'tin', 'keyboard', 'books', 'curtains', 'chopsticks', 'wire', 'drink', 'place', 'headphones', 'rack', 'cabinets', 'corn', 'word', 'trash', 'rubber', 'boxes', 'peach', 'package', 'garment', 'bed', 'stack', 'bung', 'bottom', 'fryer', 'oven', 'corner', 'it', 'clockwise', 'zip', 'sprite', 'sweet', 'whiteboard', 'kcup', 'wrapper', 'buttons', 'trousers', 'string', 'knot', 'apple', 'shoes', 'cables', 'driver', 'balls', 'sweater', 'stove', 'tokens', 'two', 'carton', 'glove', 'board', 'sink', 'plates', 'move', 'pear', 'countertop', 'plushies', 'liquid', 'remover', 'packets', 'jeans', 'adapter', 'thermos', 'slot', 'pliers', 'strings', 'forks', 'cola', 'watermelon', 'zucchini', 'pants', 'silver', 'spoons', 'teapot', 'clothe', 'mouth', 'fruit', 'cutlery', 'maize', 'blades', 'white', 'tile', 'markers', 'teabag', 'pin', 'inside', 'remotes', 'blue', 'dish', 'fabric', 'snacks', 'left', 'vial', 'pump', 'utensil', 'soap', 'bull', 'opening', 'yellow', 'ends', 'plug', 'broom', 'release', 'controller', 'cans', 'donut', 'sticks', 'hood', 'cushions', 'close', 'paddle', 'purse', 'polish', 'whisk', 'serviette', 'cucumber', 'switches', 'cereal', 'conditioner', 'window', 'degrees', 'detergent', 'roller', 'third', 'stopper', 'tote', 'downwards', 'plastics', 'cuboid', 'socket', 'potatoes', 'desk', 'garlic', 'seeds', 'usb', 'pens', 'frame', 'grape', 'pink', 'eggplant', 'tiger', 'backpack', 'rectangle', 'bolt', 'open', 'peeler', 'drawers', 'adaptor', 'green', 'ribbon', 'device', 'hangers', 'lemons', 'cloves', 'sneakers', 'dryer', 'slipper', 'action', 'cookie', 'blade', 'letters', 'gloves', 'anticlockwise', 'gluestick', 'direction', 'highlighter', 'token', 'filter', 'dishwasher', 'core', 'short', 'spice', 'end', 'pad', 'vessel', 'basin', 'battery', 'card', 'slippers ...

# %%
clustered_dict = {k: v for k, v in sorted(clustered_dict.items(), key=lambda item: len(item[1]), reverse=True)}

# %%
print(f'NUMBER OF TOTAL DEMOS: {sum(len(val) for val in clustered_dict.values())}')
for k, v in clustered_dict.items():
    print(f'{k} - {len(v)}')
# Out:
# NUMBER OF TOTAL DEMOS: 49895
# marker - 4680
# lid - 2493
# object - 2431
# towel - 2067
# cup - 2012
# pen - 1808
# bottle - 1666
# drawer - 1649
# cloth - 1441
# block - 1320
# door - 1171
# spoon - 1071
# toy - 896
# bowl - 882
# switch - 759
# mug - 691
# contents - 682
# button - 573
# objects - 519
# box - 475
# band - 434
# pot - 431
# tape - 384
# faucet - 352
# plate - 352
# cube - 331
# cable - 310
# can - 310
# screwdriver - 307
# packet - 291
# tap - 279
# cups - 269
# fork - 259
# bottles - 244
# book - 240
# shirt - 232
# glass - 228
# blocks - 217
# bag - 208
# stick - 204
# lever - 202
# ball - 197
#  - 188
# curtain - 180
# item - 178
# napkin - 178
# table - 176
# rope - 172
# paper - 159
# bin - 156
# spatula - 155
# nozzle - 150
# clothes - 147
# some - 146
# tissue - 143
# cap - 142
# plushie - 141
# container - 139
# handle - 138
# thing - 137
# remote - 135
# knife - 134
# top - 134
# pan - 133
# basket - 131
# ring - 131
# jar - 126
# bar - 125
# turn - 121
# things - 119
# pack - 119
# light - 108
# elastic - 106
# sponge - 102
# sharpie - 101
# brush - 100
# kettle - 100
# straw - 92
# clothing - 91
# cabinet - 90
# one - 90
# piece - 88
# ropes - 88
# pepper - 88
# lamp - 83
# slice - 82
# maker - 81
# tshirt - 80
# hanger - 79
# mouse - 78
# tube - 77
# pillow - 76
# knob - 75
# sachet - 75
# doll - 74
# orange - 74
# shaker - 74
# spout - 73
# duck - 73
# toaster - 73
# pencil - 71
# tool - 70
# plush - 69
# plushy - 67
# press - 67
# microwave - 65
# cellar - 62
# plastic - 62
# toys - 60
# wrench - 60
# sock - 58
# rod - 57
# rings - 56
# blanket - 55
# doors - 53
# egg - 51
# papers - 51
# charger - 51
# items - 51
# roll - 51
# towels - 50
# key - 50
# eraser - 49
# compartment - 49
# banana - 49
# pieces - 49
# shoe - 48
# toothbrush - 46
# holder - 46
# sweatshirt - 46
# laptop - 46
# cupboard - 45
# pots - 45
# case - 45
# duster - 44
# head - 44
# chair - 44
# lemon - 44
# counter - 43
# glue - 43
# pod - 42
# soda - 42
# cover - 40
# pair - 40
# shirts - 40
# control - 40
# fruits - 40
# square - 39
# bowls - 38
# cord - 37
# machine - 37
# beans - 37
# jacket - 37
# cylinder - 37
# keys - 36
# grey - 36
# stapler - 36
# car - 35
# water - 35
# grapes - 35
# cob - 34
# spoonful - 34
# brick - 33
# side - 33
# tomato - 32
# stand - 32
# position - 32
# pillows - 32
# tongs - 31
# containers - 31
# tray - 31
# carrot - 30
# socks - 30
# push - 30
# tissues - 29
# hat - 29
# lunchbox - 29
# scissors - 29
# chip - 29
# blinds - 29
# capsule - 28
# folk - 28
# peg - 28
# pineapple - 27
# lego - 27
# cloths - 27
# sweets - 27
# candy - 27
# chopstick - 26
# snack - 26
# jersey - 26
# basketball - 26
# fries - 26
# scoop - 25
# hoodie - 25
# legos - 25
# coat - 25
# part - 25
# bread - 25
# ladle - 25
# flask - 25
# letter - 25
# disc - 24
# broccoli - 24
# circles - 24
# sneaker - 24
# jug - 24
# metal - 23
# rag - 23
# sachets - 23
# right - 23
# cubes - 23
# cooker - 23
# discs - 23
# wipe - 23
# slider - 23
# caps - 22
# fleece - 22
# tiles - 22
# chamber - 22
# toothpaste - 21
# coffeemaker - 21
# circle - 21
# shelf - 21
# the - 21
# tshirts - 21
# wallet - 21
# animal - 21
# bear - 21
# belt - 20
# disk - 20
# potato - 20
# dispenser - 20
# content - 20
# chips - 20
# crayon - 19
# slices - 19
# tin - 19
# keyboard - 18
# books - 18
# curtains - 18
# chopsticks - 18
# wire - 18
# drink - 17
# place - 17
# headphones - 17
# rack - 17
# cabinets - 17
# corn - 17
# word - 17
# trash - 17
# rubber - 17
# boxes - 16
# peach - 16
# package - 16
# garment - 16
# bed - 16
# stack - 16
# bung - 16
# bottom - 16
# fryer - 16
# oven - 16
# corner - 15
# it - 15
# clockwise - 15
# zip - 15
# sprite - 15
# sweet - 15
# whiteboard - 15
# kcup - 15
# wrapper - 15
# buttons - 15
# trousers - 14
# string - 14
# knot - 14
# apple - 14
# shoes - 14
# cables - 14
# driver - 14
# balls - 14
# sweater - 14
# stove - 14
# tokens - 14
# two - 13
# carton - 13
# glove - 13
# board - 13
# sink - 13
# plates - 13
# move - 13
# pear - 13
# countertop - 13
# plushies - 12
# liquid - 12
# remover - 12
# packets - 12
# jeans - 12
# adapter - 12
# thermos - 12
# slot - 12
# pliers - 12
# strings - 12
# forks - 12
# cola - 12
# watermelon - 11
# zucchini - 11
# pants - 11
# silver - 11
# spoons - 11
# teapot - 11
# clothe - 11
# mouth - 11
# fruit - 11
# cutlery - 11
# maize - 11
# blades - 11
# white - 10
# tile - 10
# markers - 10
# teabag - 10
# pin - 10
# inside - 10
# remotes - 10
# blue - 10
# dish - 10
# fabric - 10
# snacks - 9
# left - 9
# vial - 9
# pump - 9
# utensil - 9
# soap - 9
# bull - 9
# opening - 9
# yellow - 9
# ends - 9
# plug - 9
# broom - 9
# release - 9
# controller - 9
# cans - 9
# donut - 9
# sticks - 9
# hood - 9
# cushions - 8
# close - 8
# paddle - 8
# purse - 8
# polish - 8
# whisk - 8
# serviette - 8
# cucumber - 8
# switches - 8
# cereal - 8
# conditioner - 8
# window - 8
# degrees - 8
# detergent - 8
# roller - 8
# third - 7
# stopper - 7
# tote - 7
# downwards - 7
# plastics - 7
# cuboid - 7
# socket - 7
# potatoes - 7
# desk - 7
# garlic - 7
# seeds - 7
# usb - 7
# pens - 7
# frame - 7
# grape - 7
# pink - 7
# eggplant - 7
# tiger - 7
# backpack - 7
# rectangle - 6
# bolt - 6
# open - 6
# peeler - 6
# drawers - 6
# adaptor - 6
# green - 6
# ribbon - 6
# device - 6
# hangers - 6
# lemons - 6
# cloves - 6
# sneakers - 6
# dryer - 6
# slipper - 6
# action - 6
# cookie - 6
# blade - 6
# letters - 6
# gloves - 6
# anticlockwise - 6
# gluestick - 6
# direction - 6
# highlighter - 6
# token - 6
# filter - 6
# dishwasher - 6
# core - 6
# short - 6
# spice - 6
# end - 6
# pad - 5
# vessel - 5
# basin - 5
# battery - 5
# card - 5
# slippers - 5
# mat - 5
# strawberry - 5
# snickers - 5
# umbrella - 5
# zipper - 5
# screen - 5
# shorts - 5
# trouser - 5
# colander - 5
# bat - 5
# bags - 5
# slide - 5
# coil - 5
# flusk - 5
# tubes - 5
# straws - 5
# black - 5
# surface - 5
# cushion - 5
# lift - 5
# cocacola - 5
# burger - 5
# headsets - 5
# litter - 5
# ties - 5
# lock - 5
# three - 4
# sheet - 4
# glasses - 4
# bucket - 4
# marshmallow - 4
# controls - 4
# gadget - 4
# clamp - 4
# coin - 4
# saltcellar - 4
# rabbit - 4
# twist - 4
# doughnut - 4
# center - 4
# sleeves - 4
# booklet - 4
# doritos - 4
# pumpkin - 4
# opener - 4
# upright - 4
# cupboards - 4
# fry - 4
# plant - 4
# bulbs - 4
# second - 4
# torch - 4
# section - 4
# scrunchie - 4
# fritos - 4
# saucepan - 4
# mango - 4
# candies - 4
# napkins - 4
# coins - 4
# pee - 4
# popcorn - 3
# pizza - 3
# jumper - 3
# screw - 3
# clip - 3
# microphone - 3
# scarf - 3
# salt - 3
# edge - 3
# packs - 3
# folks - 3
# grains - 3
# everything - 3
# mitt - 3
# racket - 3
# knives - 3
# mitten - 3
# tag - 3
# sugar - 3
# powder - 3
# nut - 3
# brown - 3
# loader - 3
# bricks - 3
# mugs - 3
# appliance - 3
# fabrics - 3
# magazine - 3
# flop - 3
# airfryer - 3
# helmet - 3
# marble - 3
# novel - 3
# portion - 3
# plum - 3
# panel - 3
# bins - 3
# phone - 3
# forwards - 3
# bean - 3
# serviettes - 3
# gameboard - 3
# strainer - 3
# pile - 3
# vaseline - 3
# arm - 3
# notebook - 3
# trainer - 3
# fanta - 3
# cupcake - 3
# clove - 3
# watering - 3
# squares - 3
# vegetable - 3
# whisker - 3
# couch - 3
# sleeve - 3
# duvet - 3
# dress - 3
# line - 3
# spanner - 3
# remove - 3
# heap - 3
# measure - 3
# clock - 3
# red - 3
# sponges - 3
# you - 3
# tower - 3
# nearer - 2
# stir - 2
# dishrack - 2
# moose - 2
# pick - 2
# kitchen - 2
# leaf - 2
# park - 2
# iron - 2
# dresser - 2
# liner - 2
# drawing - 2
# aircon - 2
# lids - 2
# scribbles - 2
# floss - 2
# e - 2
# gun - 2
# seasoning - 2
# cookers - 2
# stacks - 2
# tsheet - 2
# u - 2
# dishwashing - 2
# holders - 2
# cone - 2
# barrier - 2
# sunglasses - 2
# lays - 2
# shade - 2
# tablet - 2
# vest - 2
# upside - 2
# spray - 2
# lunchboxs - 2
# unit - 2
# fridge - 2
# chocolate - 2
# inwards - 2
# flowerpot - 2
# speaker - 2
# positions - 2
# avocado - 2
# weight - 2
# rail - 2
# chapstick - 2
# softener - 2
# scale - 2
# bunch - 2
# wrap - 2
# teddy - 2
# toolbox - 2
# magnet - 2
# crate - 2
# tv - 2
# rice - 2
# crayons - 2
# blender - 2
# slicer - 2
# plunger - 2
# bow - 2
# envelope - 2
# reservoir - 2
# grain - 2
# spring - 2
# funnel - 2
# lead - 2
# chicken - 2
# bandana - 2
# scooper - 2
# seals - 2
# flower - 2
# cape - 2
# r - 2
# substance - 2
# middle - 2
# use - 2
# laces - 2
# purple - 2
# counterclockwise - 2
# watch - 2
# sleeper - 2
# receipt - 2
# pairs - 2
# lights - 2
# coffee - 2
# boot - 2
# pice - 2
# air - 2
# hammer - 2
# slabs - 2
# mirror - 2
# draw - 2
# sets - 2
# pods - 2
# grate - 2
# jean - 2
# tripod - 1
# writing - 1
# heater - 1
# octopus - 1
# rubbish - 1
# pincers - 1
# packaging - 1
# peace - 1
# face - 1
# flag - 1
# satchet - 1
# sanitizer - 1
# other - 1
# creeper - 1
# pane - 1
# stirrers - 1
# marbles - 1
# covers - 1
# pearl - 1
# teaspoon - 1
# pellets - 1
# note - 1
# reck - 1
# mini - 1
# both - 1
# handles - 1
# hose - 1
# controllers - 1
# sphere - 1
# potholder - 1
# boards - 1
# storage - 1
# flashlight - 1
# front - 1
# tshit - 1
# bedspread - 1
# drawerput - 1
# tilt - 1
# maroon - 1
# bedsheet - 1
# detangle - 1
# potput - 1
# most - 1
# cream - 1
# tablespoon - 1
# platforms - 1
# monitor - 1
# sorter - 1
# folder - 1
# floral - 1
# towerput - 1
# cylinders - 1
# platform - 1
# beanie - 1
# notepad - 1
# sides - 1
# nail - 1
# stethoscope - 1
# tie - 1
# wiper - 1
# dishcloth - 1
# flip - 1
# desks - 1
# tab - 1
# bun - 1
# tapwet - 1
# blush - 1
# peels - 1
# pancake - 1
# sign - 1
# football - 1
# colourless - 1
# cases - 1
# barrel - 1
# places - 1
# milk - 1
# writings - 1
# extension - 1
# handful - 1
# bock - 1
# ta - 1
# placemat - 1
# suitcase - 1
# flyer - 1
# set - 1
# grabfull - 1
# canister - 1
# taps - 1
# ease - 1
# pond - 1
# dial - 1
# oximeter - 1
# plies - 1
# marshmallows - 1
# greater - 1
# yogurt - 1
# radish - 1
# foam - 1
# candle - 1
# pillowcase - 1
# fan - 1
# grounds - 1
# shaving - 1
# shapes - 1
# greenwhite - 1
# movement - 1
# cheetah - 1
# overhead - 1
# lump - 1
# ducky - 1
# take - 1
# humans - 1
# tulip - 1
# masks - 1
# grating - 1
# headset - 1
# sofa - 1
# cardboard - 1
# satchel - 1
# cop - 1
# hamburger - 1
# all - 1
# back - 1
# blenders - 1
# strap - 1
# something - 1
# nest - 1
# eyewash - 1
# photo - 1
# mouthwash - 1
# wrappers - 1
# zealots - 1
# kid - 1
# furthest - 1
# rapper - 1
# strips - 1
# armrest - 1
# z - 1
# tweezers - 1
# wheat - 1
# cupbowl - 1
# x - 1
# closet - 1
# lighter - 1
# pages - 1
# dustbin - 1
# loaf - 1
# doortake - 1
# gray - 1
# way - 1
# dog - 1
# sellotape - 1
# potatoe - 1
# stamp - 1
# foil - 1
# computer - 1
# vegetables - 1
# denim - 1
# juice - 1
# bands - 1
# animals - 1
# mitts - 1
# extensions - 1
# beads - 1
# shoebox - 1
# mit - 1
# beetroot - 1
# callipers - 1
# garbage - 1
# sushi - 1
# bulb - 1
# yoghurt - 1
# specks - 1
# words - 1
# tupperware - 1
# hoop - 1
# fog - 1
# dumbbell - 1
# deodorant - 1
# bank - 1
# shovel - 1
# power - 1
# decoder - 1
# firm - 1
# material - 1
# beddings - 1
# pans - 1
# tangerine - 1
# novels - 1
# zipties - 1
# sacket - 1
# net - 1
# tabletop - 1
# stuff - 1
# over - 1
# machines - 1
# macbook - 1
# deer - 1
# syrup - 1
# griddle - 1
# bracelet - 1
# steak - 1
# drawertake - 1
# brewer - 1
# rolls - 1
# leaflet - 1
# bows - 1
# truck - 1
# knobs - 1
# ipad - 1
# magazines - 1
# sleepers - 1
# utensils - 1
# sheets - 1
# load - 1
# notepads - 1
# flier - 1
# salmon - 1
# products - 1
# eyeglasses - 1
# worms - 1
# circuit - 1
# console - 1
# spacebar - 1
# keyholder - 1
# boxstack - 1
# unravel - 1
# snuck - 1
# sprayer - 1
# timer - 1
# thandle - 1
# markup - 1
# pebble - 1
# thrice - 1
# conditioning - 1
# flake - 1
# cutter - 1
# leg - 1
# first - 1
# parts - 1
# headbend - 1
# sandal - 1
# latch - 1
# four - 1
# shoulder - 1
# caddy - 1
# detach - 1
# sweep - 1
# icon - 1
# raspberry - 1
# apples - 1
# backrest - 1
# strip - 1
# underwear - 1
# vinegar - 1
# mittens - 1
# frechfry - 1
# marrow - 1
# bridge - 1
# scope - 1
# shaver - 1
# bowels - 1
# zeros - 1
# kettles - 1
# bears - 1
# hook - 1
# bananas - 1
# radio - 1
# waste - 1
# lunchboxes - 1
# bandaid - 1
# rightside - 1
# thermocup - 1
# comb - 1
# scrunchies - 1
# grill - 1
# tub - 1

# %%
# Compare similarity between extracted objects
keys = list(clusters_dict.keys())
sentences = []
for values in clusters_dict.values():
    for value in values:
        sentences.append(value[1])

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(keys)
similarity_matrix = cosine_similarity(tfidf_matrix)

HYPERPARAMETER_TAU = 9
linked = linkage(similarity_matrix, 'ward')
labels = fcluster(linked, t=HYPERPARAMETER_TAU, criterion='distance')

label_to_key = {label: key for label, key in zip(labels, keys)}

result_dict = {}
for label, demos in zip(labels, clusters_dict.values()):
    key = label_to_key[label]
    if key not in result_dict:
        result_dict[key] = []
    result_dict[key].extend(demos) 

result_dict = {k: v for k, v in sorted(result_dict.items(), key=lambda item: len(item[1]), reverse=True)}

# %%
FILE_PATH = "roughly_clustered_demos.pkl"
with open(FILE_PATH, "wb") as f:
    pickle.dump(result_dict, f)
